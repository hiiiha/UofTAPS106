# %% [markdown]
# # APS106 - Fundamentals of Computer Programming
# ## Design Project 1: Forward Kinematics (Completed Notebook)
#
# ### Lecture Structure
# 1. [Problem Background](#section1)
# 2. [Define The Problem](#section2)
# 3. [Define Test Cases](#section3)
# 4. [Generate Creative Solutions](#section4)
# 5. [Select a Solution](#section5)
# 6. [Implement the Solution](#section6)
# 7. [Perform Final Testing](#section7)
# 8. [Iterate On Feedback](#section8)
# 9. [Interactive Visualization](#section9)

# %% [markdown]
# <a id='section1'></a>
# ## 1. Problem Background
# If you have a robotic arm (e.g., the Canadarm) with joints, it is important to be able to calculate where the end of the arm (i.e., the part usually used for picking something up) will be based on the characteristics of the arm (e.g., the length of the components) and the angles of its joints.
# <br>
# <img src="images/Arm.png" alt="drawing" width="400"/>
# <br>
# Forward kinematics is the use of the kinematic equations of a robot to compute the position of the end of the arm (end-effector) from specified values for the joint parameters. Forward kinematics is used heavily in robotics, computer games, and animation.
#
# <br>
# <img src="images/ArmMath.png" alt="drawing" width="400"/>
# <br>
# <a id='section2a'></a>

# %% [markdown]
# <a id='section2'></a>
# ## 2. Define The Problem
# Given a robotic arm with two degrees of freedom (see above diagram), determine the position `(x,y)` of the effector given the component-arm lengths and joint angles.
#
# **Base Coordinate:** We need to find the `x` and `y` coordinates of the end of the arm. Those coordinates will obviously depend on the location of the base of the arm. And so a relevant question to the client is whether we can define our own coordinate system or if there is a larger system that this arm is part of. Let’s assume that we can define our own coordinate system with the base of the arm at `(0, 0)`.
#
# **Something To Think About:** How expensive will it be if this assumption is wrong? Will we have to throw away all our work and start again? Or is there likely to be an easy way to take a solution with a fixed coordinate system and reuse it in an externally specified coordinate system?

# %% [markdown]
# <a id='section3'></a>
# ## 3. Define Test Cases
# ### Test Case 1
# `len1 = 1, len2 = 1, ang1 = 60, ang2 = 30`
# <br>
# <img src="images/test1.png" alt="drawing" width="200"/>
# <br>
# End effector position `x = 0.5, y = 1.87`
#
# ### Test Case 2
# `len1 = 1, len2 = 1, ang1 = 60, ang2 = -30`
# <br>
# <img src="images/test2.png" alt="drawing" width="200"/>
# <br>
# End effector position `x = 1.37, y = 1.37`
#
# ### Test Case 3
# $\text{len1} = \sqrt{8^2 + 4^2} = 8.95, \text{len2} = \sqrt{2^2 + 4^2} = 4.47, \text{ang1} = {26.6}, \text{ang2} = {-90}$
# <br>
# <img src="images/test3.png" alt="drawing" width="400"/>
# <br>
# End effector position `x = 10, y = 0`
#
# Where do these test cases come from? Either the client gives them to you or you have to figure out from first principles (or research) how to calculate the answers by hand.

# %% [markdown]
# <a id='section4'></a>
# ## 4. Generate Creative Solutions
# <br>
# <img src="images/xyfinder.png" alt="drawing" width="500"/>
# <br>
# Based on simple math, we can obtain the ($\Delta x_1$, $\Delta y_1$) position of the end of the first component arm.
#
# \begin{align}
# \Delta x_1 & = L_1\cos(\theta_1) \\
# \Delta y_1 & = L_1\sin(\theta_1)
# \end{align}
#
# Then we can obtain the ($\Delta x_2$, $\Delta y_2$) position for arm 2.
#
# \begin{align}
# \Delta x_2 & = L_2\cos(\theta_2 + \theta_1) \\
# \Delta y_2 & = L_2\sin(\theta_2 + \theta_1)
# \end{align}
#
# Finally, we can find the `(x,y)` position by adding up the components.
#
# \begin{align}
# x & = \Delta x_1+ \Delta x_2 \\
# y & = \Delta y_1+ \Delta y_2
# \end{align}
#
# #### These steps nicely form an Algorithm Plan
# 1. Get arm lengths and angles from the user.
# 1. Calculate `(x,y)` position of the end of arm 1.
# 1. Calculate the `(x,y)` position of the end of arm 2.
# 1. Add up the components.
#
# Another solution may arise from the observation that the x and y dimensions can be solved independently. Does this observation fundamentally change the solution?
#
# #### How about a Programming Plan? How should we go about implementing the above?
# 1. Get the input and store it in variables.
# 1. Implement calculation of $\Delta x_1$ and $\Delta y_1$ from the inputs and test.
# 1. Implement calculation $\Delta x_2$ and $\Delta y_2$ from the inputs and test.
# 1. Calculate `x` and `y` from the deltas.

# %% [markdown]
# <a id='section5'></a>
# ## 5. Select a Solution
# As the single solution looks straightforward (since the problem is pretty easy), we can select it and proceed.

# %% [markdown]
# <a id='section6'></a>
# ## 6. Implement the Solution
# Let's write the **Algorithm Plan** as comments.

# %%
import math

# Get lengths and angles
length1_str = input("Length of arm 1:")
length1 = float(length1_str)                                     # change to float type

angle1_str = input("Angle between arm 1 and ground, degrees:")   # in degrees
angle1 = math.radians(float(angle1_str))                         # change to float and radians

length2_str = input("Length of arm 2:")
length2 = float(length2_str)                                     # change to float type

angle2_str = input("Angle between arm 1 and 2, degrees:")
angle2 = math.radians(float(angle2_str))

# Calculate the relative end of Arm 1
delta_x1 = math.cos(angle1) * length1
delta_y1 = math.sin(angle1) * length1

# Calculate the relative end of Arm 2
delta_x2 = math.cos(angle1 + angle2) * length2
delta_y2 = math.sin(angle1 + angle2) * length2

# Add up the components and calculate the final x, y position
final_x = delta_x1 + delta_x2
final_y = delta_y1 + delta_y2

print(final_x)
print(final_y)
# Out:
# 0.5000000000000002
# 1.8660254037844386

# %% [markdown]
# ### Programming Step 1: Get input and store it in variables
# #### Breakout Session 1
# Fill in the code below that should prompt the user for two lengths and two angles.

# %%
# Get lengths and angles
len1 = input("Length of arm 1:") # Use 1 from the first test case for quick testing
ang1 = input("Angle between arm 1 and ground, degrees:") # Use 60 degrees from the first test case for quick testing
len2 = input("Length of arm 2:") # Use 1 from the first test case for quick testing
ang2 = input("Angle between arm 1 and 2, degrees:") # Use 30 degrees from the first test case for quick testing

print("Arm 1: Length =", len1, ', Angle =', ang1)
print("Arm 2: Length =", len2, ', Angle =', ang2)

# Calculate the relative end of Arm 1

# Calculate the relative end of Arm 2

# Add up the components and calculate the final x, y position
# Out:
# Arm 1: Length = 1 , Angle = 60
# Arm 2: Length = 1 , Angle = 30

# %% [markdown]
# ### Programming Step 2 – Implement calculation of $\Delta x_1$ and $\Delta y_1$ from the inputs and test
# \begin{align}
# \Delta x_1 & = L_1\cos(\theta_1) \\
# \Delta y_1 & = L_1\sin(\theta_1)
# \end{align}

# %%
# Get lengths and angles
len1 = input("Length of arm 1:") # Use 1 from the first test case for quick testing
ang1 = input("Angle of arm 1:")  # Use 60 from the first test case for quick testing
len2 = input("Length of arm 2:") # Use 1 from the first test case for quick testing
ang2 = input("Angle of arm 2:")  # Use 30 from the first test case for quick testing

print("Arm 1: Length =", len1, ', Angle =', ang1)
print("Arm 2: Length =", len2, ', Angle =', ang2)

# Calculate the relative end of Arm 1
dx1 = ...
dy1 = ...

# Calculate the relative end of Arm 2

# Add up the components and calculate the final x, y position

# %% [markdown]
# Hmm ... Any idea what the problem is?

# %%
# Get lengths and angles
len1 = input("Length of arm 1:") # Use 1 from the first test case for quick testing
ang1 = input("Angle of arm 1:")  # Use 60 from the first test case for quick testing
len2 = input("Length of arm 2:") # Use 1 from the first test case for quick testing
ang2 = input("Angle of arm 2:")  # Use 30 from the first test case for quick testing

print("Arm 1: Length =", len1, ', Angle =', ang1)
print("Arm 2: Length =", len2, ', Angle =', ang2)

# Calculate the relative end of Arm 1
dx1 = len1 * math.cos(ang1)
dy1 = len1 * math.sin(ang1)

# Calculate the relative end of Arm 2

# Add up the components and calculate the final x, y position

# %% [markdown]
# 😡 We still have a problem. What is going on?
#
# Can someone figure out what the problem is?

# %%
import math

# Get lengths and angles
len1 = input("Length of arm 1:") # Use 1 from the first test case for quick testing
ang1 = input("Angle of arm 1:")  # Use 60 from the first test case for quick testing
len2 = input("Length of arm 2:") # Use 1 from the first test case for quick testing
ang2 = input("Angle of arm 2:")) # Use 30 from the first test case for quick testing

print("Arm 1: Length =", len1, ', Angle =', ang1)
print("Arm 2: Length =", len2, ', Angle =', ang2)

# Calculate the relative end of Arm 1
dx1 = len1 * math.cos(ang1)
dy1 = len1 * math.sin(ang1)

# Calculate the relative end of Arm 2

# Add up the components and calculate the final x, y position

# %% [markdown]
# ### Programming Step 3 – Implement calculation of $\Delta x_2$ and $\Delta y_2$ from the inputs and test
# \begin{align}
# \Delta x_2 & = L_2\cos(ang_2 + ang_1) \\
# \Delta y_2 & = L_2\sin(ang_2 + ang_1) \\
# \end{align}

# %%
import math

# Get lengths and angles
len1 = float(input("Length of arm 1:")) # Use 1 from the first test case for quick testing
ang1 = float(input("Angle of arm 1:"))  # Use 60 from the first test case for quick testing
len2 = float(input("Length of arm 2:")) # Use 1 from the first test case for quick testing
ang2 = float(input("Angle of arm 2:"))  # Use 30 from the first test case for quick testing

print("Arm 1: Length =", len1, ', Angle =', ang1)
print("Arm 2: Length =", len2, ', Angle =', ang2)

# Calculate the relative end of Arm 1
dx1 = len1 * math.cos(ang1)
dy1 = len1 * math.sin(ang1)

# Calculate the relative end of Arm 2
dx2 = ...
dy2 = ...

# Add up the components and calculate the final x, y position

# %% [markdown]
# ### Programming Step 4 – Implement calculation of $x$ and $y$
# \begin{align}
# x & = x_1 + x_2 \\
# y & = y_1 + y_2 \\
# \end{align}

# %%
import math

# Get lengths and angles
len1 = float(input("Length of arm 1:")) # Use 1 from the first test case for quick testing
ang1 = float(input("Angle of arm 1:"))  # Use 60 from the first test case for quick testing
len2 = float(input("Length of arm 2:")) # Use 1 from the first test case for quick testing
ang2 = float(input("Angle of arm 2:"))  # Use 30 from the first test case for quick testing

print("Arm 1: Length =", len1, ', Angle =', ang1)
print("Arm 2: Length =", len2, ', Angle =', ang2)

# Calculate the relative end of Arm 1
dx1 = len1 * math.cos(ang1)
dy1 = len1 * math.sin(ang1)

# Calculate the relative end of Arm 2
dx2 = len2 * math.cos(ang1 + ang2)
dy2 = len2 * math.sin(ang1 + ang2)

# Add up the components and calculate the final x, y position
x = ...
y = ...

print('x =', x, ', y =', y)

# %% [markdown]
# <a id='section7'></a>
# ## 7. Perform Final Testing
# Let's check our code using the first test case.
# ### Test Case 1
# `len1 = 1, len2 = 1, ang1 = 60, ang2 = 30`
# <br>
# <img src="images/test1.png" alt="drawing" width="200"/>
# <br>
# End effector position `x = 0.5, y = 1.87`

# %%
import math

# Get lengths and angles
len1 = float(input("Length of arm 1:")) # Use 1 from the first test case for quick testing
ang1 = float(input("Angle of arm 1:"))  # Use 60 from the first test case for quick testing
len2 = float(input("Length of arm 2:")) # Use 1 from the first test case for quick testing
ang2 = float(input("Angle of arm 2:"))  # Use 30 from the first test case for quick testing

print("Arm 1: Length =", len1, ', Angle =', ang1)
print("Arm 2: Length =", len2, ', Angle =', ang2)

# Calculate the relative end of Arm 1
dx1 = len1 * math.cos(ang1)
dy1 = len1 * math.sin(ang1)

# Calculate the relative end of Arm 2
dx2 = len2 * math.cos(ang2)
dy2 = len2 * math.sin(ang2)

# Add up the components and calculate the final x, y position
x = dx1 + dx2
y = dy1 + dy2

print('x =', x, ', y =', y)

# %% [markdown]
# Hmm... Any idea what the issue is?

# %% [markdown]
# #### Breakout Session 2
# Fix the code below so it passes all Test Cases.
#
# ##### Test Case 1
# `len1 = 1`, `len2 = 1`, `ang1 = 60`, `ang2 = 30`. End effector position `x = 0.5`, `y = 1.87`
#
# ##### Test Case 2
# `len1 = 1`, `len2 = 1`, `ang1 = 60`, `ang2 = -30`. End effector position `x = 1.37`, `y = 1.37`
#
# ##### Test Case 3
# `len1 = 8.95`, `len2 = 4.47`, `ang1 = 26.6`, `ang2 = -90`. End effector position `x = 10`, `y = 0`

# %%
import math

# Get lengths and angles
len1 = float(input("Length of arm 1:")) # Use 1 from the first test case for quick testing
ang1 = float(input("Angle of arm 1:"))  # Use 60 from the first test case for quick testing
len2 = float(input("Length of arm 2:")) # Use 1 from the first test case for quick testing
ang2 = float(input("Angle of arm 2:"))  # Use 30 from the first test case for quick testing

print("Arm 1: Length =", len1, ', Angle =', ang1)
print("Arm 2: Length =", len2, ', Angle =', ang2)

# Calculate the relative end of Arm 1
dx1 = len1 * math.cos(ang1)
dy1 = len1 * math.sin(ang1)

# Calculate the relative end of Arm 2
dx2 = len2 * math.cos(ang2)
dy2 = len2 * math.sin(ang2)

# Add up the components and calculate the final x, y position
x = dx1 + dx2
y = dy1 + dy2

print('x =', x, ', y =', y)
# Out:
# Arm 1: Length = 1.0 , Angle = 60.0
# Arm 2: Length = 1.0 , Angle = 30.0
# x = -0.7981615305275722 , y = -1.2928422451950785

# %% [markdown]
# <a id='section8'></a>
# ## 8. Iterate On Feedback
# The code above gets us the right answer, BUT, there is more to writing `#cleancode`. The code above is not modular, it's not easily reusable, and I wouldn't be keen to collaborate on it.
#
# ### Breakout Session 3
# Let's use functions to improve this code. Complete the functions below using the working code above.

# %%
import math

def calculate_dx(length, angle):
    """
    (number, number) -> number
    Calculate the x-coordinate of an arm of length len with angle ang in radians. Parameter angle is in degrees.
    """
    ...
    return ...

def calculate_dy(length, angle):
    """
    (number, number) -> number
    Calculate the y-coordinate of an arm of length len with angle ang in radians. Parameter angle is in degrees.
    """
    ...
    return ...

def calculate_end_effector_position(len1, ang1, len2, ang2):
    """
    (number, number, number, number) -> number, number
    Calculate the end effector position of a two-arm system. Parameters ang1 and ang2 are in degrees.
    """
    # Convert angles to radians
    ...
    
    # Calculate end of arm 1
    ...
    
    # Calculate end of arm 2 (independently of arm 1)
    ...
    
    # Sum the individual displacements
    ...
    
    return ...

# %% [markdown]
# ##### Test Case 1
# `len1 = 1`, `len2 = 1`, `ang1 = 60`, `ang2 = 30`. End effector position `x = 0.5`, `y = 1.87`

# %%
print(calculate_end_effector_position(1, 60, 1, 30))

# %% [markdown]
# ##### Test Case 2
# `len1 = 1`, `len2 = 1`, `ang1 = 60`, `ang2 = -30`. End effector position `x = 1.37`, `y = 1.37`

# %%
print(calculate_end_effector_position(1, 60, 1, -30))

# %% [markdown]
# ##### Test Case 3
# `len1 = 8.95`, `len2 = 4.47`, `ang1 = 26.6`, `ang2 = -90`. End effector position `x = 10`, `y = 0`

# %%
print(calculate_end_effector_position(8.95, 26.6, 4.47, -90))

# %% [markdown]
# And now we can use this function with the user inputs.

# %%
# Get lengths and angles
len1 = float(input("Length of arm 1:"))
ang1 = float(input("Angle of arm 1:")) 
len2 = float(input("Length of arm 2:"))
ang2 = float(input("Angle of arm 2:")) 

print("Arm 1: Length =", len1, ', Angle =', ang1)
print("Arm 2: Length =", len2, ', Angle =', ang2)

x, y = calculate_end_effector_position(len1, ang1, len2, ang2)

print('x =', x, ', y =', y)

# %% [markdown]
# <a id='section9'></a>
# ## 9. Interactive Visualization

# %%
import math
from utils import plot_end_effector_position

def calculate_end_effector_position_visualization(len1, ang1, len2, ang2):
    """
    (number, number, number, number) -> (number, number)
    Calculate the end effector position
    """
    # Convert angles
    ang1 = math.radians(ang1) 
    ang2 = math.radians(ang2) 
    
    # Calculate end of arm 1
    dx1 = calculate_dx(len1, ang1)
    dy1 = calculate_dy(len1, ang1)
    
    # Calculate end of arm 2 (independently of arm 1)
    dx2 = calculate_dx(len2, ang1 + ang2)
    dy2 = calculate_dy(len2, ang1 + ang2)
    
    # Sum the individual displacements
    x = dx1 + dx2
    y = dy1 + dy2
    
    return dx1, dy1, dx2, dy2, x, y

plot_end_effector_position(calculate_end_effector_position_visualization)
