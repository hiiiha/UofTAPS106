# %% [markdown]
# # Question 1

# %% [markdown]
# #### What is the output of the following code?

# %% [markdown]
# ```
# num = str(10) * 3
# print(int(num) + 3)
# ```
#
# - 16
# - 33
# - 101013
# - 1010103
# - Error

# %% [markdown]
# ## Question 2

# %% [markdown]
# #### What is the output of the following code?

# %% [markdown]
# ```
# def foo():
#     if bool(1):
#         print("Good evening")
#     else:
#         return 0
#
# bar = foo()
# print(bar)
# ```
#
# - 0
# - None
# - Good evening
# - Good evening
#
#    None
# - 0
#
#    None

# %% [markdown]
# ## Question 3

# %% [markdown]
# #### What is the output of the following code?

# %% [markdown]
# ```
# def cmp():
#     word1 = "APS106"
#     word2 = "APS360"
#
#     i = 0
#     while i < 6:
#         c1 = word1[i]
#         c2 = word2[i]
#
#         if ord(c1) < ord(c2):
#             return word1
#         elif ord(c1) > ord(c2):
#             return word2
#
#         i += 1
#
# course = cmp()
# print(course)
# ```
#
# - 1
# - APS106
# - APS360
# - None
# - Error

# %% [markdown]
# ## Question 4

# %%
def dozen_egg_checker(eggs):
    if eggs % 12 == 0:
        return False
    else:
        return True

eggs = 13
print(dozen_egg_checker(eggs))

eggs = 24
print(dozen_egg_checker(eggs))

# %% [markdown]
# Select statements equivalent to the statements above:
# - return eggs%12 == 0
# - return not eggs % 12 == 0
# - return not(eggs % 12 != 0)
# - return eggs % 12 != 0

# %% [markdown]
# ## Question 5

# %% [markdown]
# #### What are the values of the variables x, y, and z after line 40 this program?

# %% [markdown]
# ```
# x = 2.1
# y = 88
# z = x // 2
#
# print(x, y, z)
#
# if x >= 2:
#     y += 10
# else:
#     y -= 10
#
# y = -y
# x = (z ** 3) % 4
#
# print(x, y, z)
# ```

# %% [markdown]
# - 1.0, 0, 1.05
# - 1.0, -78, 1.0
# - 1, -98, 1
# - 1.0, -98, 1.0

# %% [markdown]
# ## Question 6

# %% [markdown]
# #### What line below is equivalent to mystery_func(x,y,z)?
#
# - min(x,y,z)
# - max(x,y,z)
# - min(x-z, z-y, 0)
# - min(x-z, z-y)

# %%
def mystery_func(x, y, z):
    if x - z >= 0 and z - y <= 0:
        return z
    elif x >= y:
        return y
    else:
        return x

# %% [markdown]
# ## Question 7

# %% [markdown]
# #### What is printed when the code below is run?

# %% [markdown]
# ```
# course = 'aps106'
# new_str = ''
#
# i = 0
# while i < len(course):
#     if i % 2 == 0:
#         new_str = new_str + course[i].upper()
#     else:
#         new_str = new_str + course[i-1] * 2
#
#     i += 1
#
# print(new_str)
# ```

# %% [markdown]
# ## Coding Problem #1

# %%
def inverse_tanh(x, N):
    """
    (number, number) -> number

    (float, int) -> float -- would also  be acceptable

    Calculates an estimate of the inverse hyperbolic tangent function
    """
    # TODO: Your Code HERE


# TODO: Get the values from the user
x = ...
N = ...

# TODO: Handle invalid inputs

# Call the function
r = inverse_tanh(x, N)

# TODO: Print the result

# %% [markdown]
# ## Coding Problem #2

# %%
#Your Code HERE

percentage = ...

print("Customer Questions:")
print(percentage)

# %% [markdown]
# ## Coding Problem #3

# %%
# write conversations to file

# get the name and date
name = input("Enter a name: ")
date = input("Enter a date (YYYMMDD): ")

# TODO: generate the filename

# TODO: open the file for writing

# TODO: get text input from user


# TODO: close the file

# %%
# After writing the code, open "{name}_{date}_convo_log.txt" and 
# check what's written there!
filename = # Your file name

# open file for reading
f = open(filename, "r")

content = f.readline()
while content != "":
    print(content, end="")
    content = f.readline()
    i += 1

f.close()
